# %%
import sklearn 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
tf=pd.read_csv('Unemployment in India.csv')
tf
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
tf.tail(30)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 738  Uttarakhand   31-05-2020    Monthly                             17.36
# 739  Uttarakhand   30-06-2020    Monthly                              5.08
# 740  West Bengal   31-05-2019    Monthly                              7.25
# 741  West Bengal   30-06-2019    Monthly                              7.38
# 742  West Bengal   31-07-2019    Monthly                              7.91
# 743  West Bengal   31-08-2019    Monthly                              7.27
# 744  West Bengal   30-09-2019    Monthly                              7.79
# 745  West Bengal   31-10-2019    Monthly                              7.83
# 746  West Bengal   30-11-2019    Monthly                              6.61
# 747  West Bengal   31-12-2019    Monthly                              7.24
# 748  West Bengal   31-01-2020    Monthly                              7.27
# ...

# %%
tf.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
tf=tf.dropna()

# %%
tf.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
tf
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
tf = tf.rename(columns={' Date':'Date',' Frequency':'Frequency',' Estimated Employed':'Estimated_Employed',' Estimated Labour Participation Rate (%)':'Estimated_labour_participation_rate',' Estimated Unemployment Rate (%)':'Estimated_Unemployment_Rate'})

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Region                               740 non-null    object
#  1   Date                                 740 non-null    object
#  2   Frequency                            740 non-null    object
#  3   Estimated_Unemployment_Rate          740 non-null    float64
#  4   Estimated_Employed                   740 non-null    float64
#  5   Estimated_labour_participation_rate  740 non-null    float64
#  6   Area                                 740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
tf['Date']=tf['Date'].str.replace(' ','')

# %%
tf['year']=pd.DatetimeIndex(tf['Date']).year
tf['month']=pd.DatetimeIndex(tf['Date']).month
tf
# Out:
#              Region        Date Frequency  Estimated_Unemployment_Rate  \
# 0    Andhra Pradesh  31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh  30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh  31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh  31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh  30-09-2019   Monthly                         5.17
# ..              ...         ...       ...                          ...
# 749     West Bengal  29-02-2020   Monthly                         7.55
# 750     West Bengal  31-03-2020   Monthly                         6.67
# 751     West Bengal  30-04-2020   Monthly                        15.63
# 752     West Bengal  31-05-2020   Monthly                        15.22
# 753     West Bengal  30-06-2020   Monthly                         9.86
#
#      Estimated_Employed  Estimated_labour_participation_rate   Area  year  \
# ...

# %%
tf=tf.drop(columns=['Date'])
tf
# Out:
#              Region Frequency  Estimated_Unemployment_Rate  \
# 0    Andhra Pradesh   Monthly                         3.65
# 1    Andhra Pradesh   Monthly                         3.05
# 2    Andhra Pradesh   Monthly                         3.75
# 3    Andhra Pradesh   Monthly                         3.32
# 4    Andhra Pradesh   Monthly                         5.17
# ..              ...       ...                          ...
# 749     West Bengal   Monthly                         7.55
# 750     West Bengal   Monthly                         6.67
# 751     West Bengal   Monthly                        15.63
# 752     West Bengal   Monthly                        15.22
# 753     West Bengal   Monthly                         9.86
#
#      Estimated_Employed  Estimated_labour_participation_rate   Area  year  \
# 0            11999139.0                                43.24  Rural  2019
# 1            11755881.0                                42.05  Rural  2019
# ...

# %%
tf=tf.drop(columns=['Frequency'])
tf
# Out:
#              Region  Estimated_Unemployment_Rate  Estimated_Employed  \
# 0    Andhra Pradesh                         3.65          11999139.0
# 1    Andhra Pradesh                         3.05          11755881.0
# 2    Andhra Pradesh                         3.75          12086707.0
# 3    Andhra Pradesh                         3.32          12285693.0
# 4    Andhra Pradesh                         5.17          12256762.0
# ..              ...                          ...                 ...
# 749     West Bengal                         7.55          10871168.0
# 750     West Bengal                         6.67          10806105.0
# 751     West Bengal                        15.63           9299466.0
# 752     West Bengal                        15.22           9240903.0
# 753     West Bengal                         9.86           9088931.0
#
#      Estimated_labour_participation_rate   Area  year  month
# 0                                  43.24  Rural  2019      5
# ...

# %%
plt.figure(dpi=100)
plt.bar(tf['Region'],tf['Estimated_Unemployment_Rate'])
plt.xlabel('States')
plt.ylabel('Unempoyment')
# Out:
# Text(0, 0.5, 'Unempoyment')

# %%
tf.groupby('Area')['Estimated_Unemployment_Rate'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Area'>

# %%
mapping={'Rural':0,'Urban':1}
tf['Area']=tf['Area'].map(mapping)
mappingregion={'Andhra Pradesh':0, 'Assam':1, 'Bihar':2, 'Chhattisgarh':3, 'Delhi':4, 'Goa':5,
       'Gujarat':6, 'Haryana':7, 'Himachal Pradesh':8, 'Jammu & Kashmir':9,
       'Jharkhand':10, 'Karnataka':12, 'Kerala':13, 'Madhya Pradesh':14,
       'Maharashtra':15, 'Meghalaya':16, 'Odisha':17, 'Puducherry':18, 'Punjab':19,
       'Rajasthan':20, 'Sikkim':21, 'Tamil Nadu':22, 'Telangana':23, 'Tripura':24,
       'Uttar Pradesh':25, 'Uttarakhand':26, 'West Bengal':27, 'Chandigarh':28}
tf['Region']=tf['Region'].map(mappingregion)
tf['Region'].unique()
tf
# Out:
#      Region  Estimated_Unemployment_Rate  Estimated_Employed  \
# 0         0                         3.65          11999139.0
# 1         0                         3.05          11755881.0
# 2         0                         3.75          12086707.0
# 3         0                         3.32          12285693.0
# 4         0                         5.17          12256762.0
# ..      ...                          ...                 ...
# 749      27                         7.55          10871168.0
# 750      27                         6.67          10806105.0
# 751      27                        15.63           9299466.0
# 752      27                        15.22           9240903.0
# 753      27                         9.86           9088931.0
#
#      Estimated_labour_participation_rate  Area  year  month
# 0                                  43.24     0  2019      5
# 1                                  42.05     0  2019      6
# ...

# %%
X=tf.drop(columns=['Estimated_Unemployment_Rate'])
Y=tf['Estimated_Unemployment_Rate']
X.dtypes,Y.dtypes
# Out:
# (Region                                   int64
#  Estimated_Employed                     float64
#  Estimated_labour_participation_rate    float64
#  Area                                     int64
#  year                                     int64
#  month                                    int64
#  dtype: object,
#  dtype('float64'))

# %%
Y[537]
# Out:
# 3.57

# %%
from sklearn.model_selection import train_test_split as tts
x_train, x_test, y_train, y_test = tts(X, Y, test_size = 0.3, random_state = 101)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
x_train
# Out:
#      Region  Estimated_Employed  Estimated_labour_participation_rate  Area  \
# 649      20           5384335.0                                40.80     1
# 398       1           1454956.0                                38.45     1
# 434       3           2415436.0                                45.59     1
# 737      26            748041.0                                29.59     1
# 106       7           3914193.0                                42.78     0
# ..      ...                 ...                                  ...   ...
# 75        5            177155.0                                38.70     0
# 613      17           1303244.0                                25.53     1
# 589      16            228978.0                                47.79     1
# 337      26           2027662.0                                36.90     0
# 537      12           8647794.0                                39.00     1
#
#      year  month
# 649  2019     10
# 398  2020      4
# ...

# %%
from sklearn.linear_model import LinearRegression as LR
model=LR(normalize=True)
model.fit(x_train,y_train)
model.coef_
x_test.shape
# Out:
# (222, 6)

# %%
predicted_values=model.predict(x_train)
predicted_values=np.array(predicted_values)
predicted_values.reshape
# Out:
# <function ndarray.reshape>

# %%
l1=[12,8647794.0,39.00,1,2019,9]
arr=np.array(l1).reshape(1,6)
arr.shape
# Out:
# (1, 6)

# %%
ans=model.predict(arr)
ans
# Out:
# array([9.63631629])

# %%
from sklearn.metrics import r2_score
acc = r2_score(y_train,predicted_values)

print(acc)
# Out:
# 0.1452123089589935
